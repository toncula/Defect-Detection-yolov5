# %%
# !python train.py --epochs 100 --data 设备部件识别_without_ddjt_yx_tg.yaml
# Out:
# train: weights=yolov5s.pt, cfg=, data=设备部件识别_without_ddjt_yx_tg.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 2691 commits. Use 'git pull ultralytics master' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 ce4b4f7 Python-3.9.16 torch-1.13.1+cu117 CUDA:0 (GRID V100-16C, 16384MiB)
#
# ...

# %%
# !python train.py --epochs 300 --data 设备部件识别_without_ddjt_yx_tg.yaml
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Currently logged in as: wzlfly87. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=设备部件识别_without_ddjt_yx_tg.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %%
# !python detect.py --weights ~/Defect-Detection-yolov5/runs/train/exp18/weights/best.pt --source ~/Defect-Detection-yolov5/data/缺陷识别yolo/设备部件识别_without_ddjt_yx_tg/images/val
# Out:
# detect: weights=['/home/jovyan/Defect-Detection-yolov5/runs/train/exp18/weights/best.pt'], source=/home/jovyan/Defect-Detection-yolov5/data/缺陷识别yolo/设备部件识别_without_ddjt_yx_tg/images/val, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 ce4b4f7 Python-3.9.16 torch-1.13.1+cu117 CUDA:0 (GRID V100-16C, 16384MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7066762 parameters, 0 gradients, 15.9 GFLOPs
# image 1/189 /home/jovyan/Defect-Detection-yolov5/data/缺陷识别yolo/设备部件识别_without_ddjt_yx_tg/images/val/220kV_XX站-变压器-储油柜-充油设备储油柜-20190605-07.jpg: 480x640 2 cysb_cygs, 22.7ms
# ...

# %%
# !python detect.py --weights ~/Defect-Detection-yolov5/runs/train/exp18/weights/best.pt --source ~/Defect-Detection-yolov5/data/缺陷识别yolo/设备部件识别_without_ddjt_yx_tg/images/val/220kV_XX站-电流互感器-本体-20190701-25.jpg
